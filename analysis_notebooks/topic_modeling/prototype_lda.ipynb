# %%
import pandas as pd
import logging

from gensim.corpora import Dictionary

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# df = pd.read_pickle("../data/df_lemma.pkl")
lemma_grouped = pd.read_pickle("../data/df_lemma_grouped_from2018.pkl")

# %%
#df.info()

# %%
# df = df[df['lemma'].apply(len) >= 10]
lemma_grouped = lemma_grouped[lemma_grouped.apply(len) >= 10]

# %%
lemma_grouped.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 2538 entries, 396_1. Mitteilungen to 776_9. Standesinitiative zum sofortigen Stopp der Sanktionen gegen Russland und zur sofortigen Wiederinkraftsetzung der immerwährenden Neutralität der Schweiz, gemäss dem Wienerkongress von 1815
# Series name: lemma
# Non-Null Count  Dtype
# --------------  -----
# 2538 non-null   object
# dtypes: object(1)
# memory usage: 39.7+ KB

# %%
# docs = list(df['lemma'])
docs = lemma_grouped

# %%
len([1 for doc in docs if "Antworten" in doc]) / len(docs)
# Out:
# 0.10007880220646179

# %%
from collections import defaultdict

frequency = defaultdict(int)
for text in list(docs):
    for token in set(text):
        frequency[token] += 1
frequency
# Out:
# defaultdict(int,
#             {'Fragen': 650,
#              'Wirtschaft': 483,
#              'Schülerkooperation': 2,
#              'Jagdgesetz': 10,
#              'Munz': 13,
#              'Menschen': 801,
#              'Entwicklung': 614,
#              'Zürich': 1922,
#              'Kantonsrates': 709,
#              'Hübscher': 154,
#              'Kommission': 1238,
#              'Tobias': 199,
#              'Universitätsspital': 145,
#              'Heierli': 68,
#              'Pfäffikon': 114,
#              'Sola-Stafette': 2,
#              'Stunden': 190,
#              'schneller': 241,
#              'Gehrig': 120,
#              'Kehrichtverbrennungsanlagen': 13,
#              'Erlenbach': 84,
#              'letztes': 198,
#              'Regula': 25,
#              'Spitälern': 179,
#              'Gemeinderat': 162,
#              'Barbara': 340,
#              'Applaus': 181,
#              'Wädenswil': 274,
#              'Kosten': 768,
# ...

# %%
sorted_frequency = sorted(frequency.items(), key=lambda x:x[1], reverse=True)
#print(sorted_frequency)
count = 0
for f in sorted_frequency:
    if f[1]/len(docs) < 0.10:
        break
    print(f"{f[0]}: {f[1]/len(docs)}")
    count += 1
print(count)
# Out:
# Zürich: 0.7572892040977147
# Geschäft: 0.7470449172576832
# erledigt: 0.7261623325453113
# KR-Nr: 0.7206461780929866
# Antrag: 0.6765169424743893
# Kanton: 0.5921985815602837
# Regierungsrat: 0.586682427107959
# Kantonsrat: 0.5819542947202522
# SVP: 0.5732860520094563
# Fall: 0.5669818754925138
# FDP: 0.5472813238770685
# SP: 0.5240346729708432
# Stimmen: 0.516548463356974
# Kommission: 0.48778565799842394
# Vorlage: 0.48739164696611503
# einfach: 0.4511426319936958
# gestellt: 0.44129235618597323
# Abstimmung: 0.438140267927502
# Kantons: 0.43656422379826637
# bitte: 0.4318360914105595
# klar: 0.4306540583136328
# beantragt: 0.42750197005516155
# braucht: 0.4247438928289992
# gehört: 0.4168636721828211
# sagen: 0.4152876280535855
# Regierungsrates: 0.41174152876280534
# Zürcher: 0.4066193853427896
# unterstützen: 0.4030732860520095
# Paragraf: 0.3963750985027581
# unterstützt: 0.39440504334121357
# genau: 0.39440504334121357
# letzten: 0.39243498817966904
# ...

# %%
# Compute bigrams.
from gensim.models import Phrases

# Add bigrams and trigrams to docs (only ones that appear 20 times or more).
bigram = Phrases(docs, min_count=20)
for idx in range(len(docs)):
    for token in bigram[docs[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs[idx].append(token)
# Out:
# 2023-05-10 18:28:35,039 : INFO : collecting all words and their counts
# 2023-05-10 18:28:35,040 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2023-05-10 18:28:38,915 : INFO : collected 1914978 token types (unigram + bigrams) from a corpus of 2541292 words and 2538 sentences
# 2023-05-10 18:28:38,916 : INFO : merged Phrases<1914978 vocab, min_count=20, threshold=10.0, max_vocab_size=40000000>
# 2023-05-10 18:28:38,918 : INFO : Phrases lifecycle event {'msg': 'built Phrases<1914978 vocab, min_count=20, threshold=10.0, max_vocab_size=40000000> in 3.88s', 'datetime': '2023-05-10T18:28:38.918078', 'gensim': '4.3.1', 'python': '3.10.9 (main, Jan 11 2023, 15:21:40) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-1031-azure-x86_64-with-glibc2.31', 'event': 'created'}

# %%
# Create a dictionary representation of the documents.
dictionary = Dictionary(docs)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=10, no_above=0.1)
# Out:
# 2023-05-10 18:28:44,401 : INFO : adding document #0 to Dictionary<0 unique tokens: []>
# 2023-05-10 18:28:47,316 : INFO : built Dictionary<156709 unique tokens: ['155.', '23.', '23._April', '8.15', '8.15_Zuweisung']...> from 2538 documents (total 2726407 corpus positions)
# 2023-05-10 18:28:47,317 : INFO : Dictionary lifecycle event {'msg': "built Dictionary<156709 unique tokens: ['155.', '23.', '23._April', '8.15', '8.15_Zuweisung']...> from 2538 documents (total 2726407 corpus positions)", 'datetime': '2023-05-10T18:28:47.317616', 'gensim': '4.3.1', 'python': '3.10.9 (main, Jan 11 2023, 15:21:40) [GCC 11.2.0]', 'platform': 'Linux-5.15.0-1031-azure-x86_64-with-glibc2.31', 'event': 'created'}
# 2023-05-10 18:28:47,481 : INFO : discarding 136011 tokens: [('155.', 2), ('Amt', 674), ('Amtszwang', 3), ('Antworten', 254), ('April', 443), ('Barbara', 340), ('Bau', 375), ('Bedingungen', 272), ('Bereich', 832), ('Beschluss', 352)]...
# ...

# %%
corpus = [dictionary.doc2bow(doc) for doc in docs]

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 20698
# Number of documents: 2538

# %%
# Train LDA model.
from gensim.models import LdaMulticore

# Set training parameters.
num_topics = 125
chunksize = 600
passes = 20
iterations = 400
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# Make an index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model = LdaMulticore(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    #alpha='auto',
    alpha=0.75,
    eta=0.0001,
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)
# Out:
# 2023-05-10 18:28:58,171 : INFO : using serial LDA version on this node
# 2023-05-10 18:28:58,445 : INFO : running online LDA training, 125 topics, 20 passes over the supplied corpus of 2538 documents, updating every 1800 documents, evaluating every ~0 documents, iterating 400x with a convergence threshold of 0.001000
# 2023-05-10 18:28:58,448 : INFO : training LDA model using 3 processes
# 2023-05-10 18:28:58,514 : INFO : PROGRESS: pass 0, dispatched chunk #0 = documents up to #600/2538, outstanding queue size 1
# 2023-05-10 18:28:58,610 : INFO : PROGRESS: pass 0, dispatched chunk #1 = documents up to #1200/2538, outstanding queue size 2
# 2023-05-10 18:28:58,613 : INFO : PROGRESS: pass 0, dispatched chunk #2 = documents up to #1800/2538, outstanding queue size 3
# 2023-05-10 18:28:58,617 : INFO : PROGRESS: pass 0, dispatched chunk #3 = documents up to #2400/2538, outstanding queue size 4
# ...

# %%
top_topics = model.top_topics(corpus=corpus,
                              texts=docs,
                              dictionary=dictionary,
                              coherence='c_v',
                              topn=10,
                              processes=-1)
# Out:
# 2023-05-10 18:35:14,398 : INFO : using ParallelWordOccurrenceAccumulator<processes=3, batch_size=64> to estimate probabilities from sliding windows
# 2023-05-10 18:35:14,486 : INFO : 1 batches submitted to accumulate stats from 64 documents (66138 virtual)
# 2023-05-10 18:35:14,515 : INFO : 2 batches submitted to accumulate stats from 128 documents (128318 virtual)
# 2023-05-10 18:35:14,541 : INFO : 3 batches submitted to accumulate stats from 192 documents (198734 virtual)
# 2023-05-10 18:35:14,563 : INFO : 4 batches submitted to accumulate stats from 256 documents (253148 virtual)
# 2023-05-10 18:35:14,585 : INFO : 5 batches submitted to accumulate stats from 320 documents (309937 virtual)
# 2023-05-10 18:35:14,599 : INFO : 6 batches submitted to accumulate stats from 384 documents (345118 virtual)
# 2023-05-10 18:35:16,041 : INFO : 7 batches submitted to accumulate stats from 448 documents (387551 virtual)
# ...

# %%
# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)
# Out:
# Average topic coherence: 0.5686.

# %%
from gensim.models import CoherenceModel

coherence_model_lda = CoherenceModel(model=model, texts=docs, dictionary=dictionary, coherence='c_v', topn=10)
coherence_lda = coherence_model_lda.get_coherence()
print('Coherence Score: ', coherence_lda)
# Out:
# 2023-05-10 18:35:51,580 : INFO : using ParallelWordOccurrenceAccumulator<processes=3, batch_size=64> to estimate probabilities from sliding windows
# 2023-05-10 18:35:51,676 : INFO : 1 batches submitted to accumulate stats from 64 documents (66138 virtual)
# 2023-05-10 18:35:51,707 : INFO : 2 batches submitted to accumulate stats from 128 documents (128318 virtual)
# 2023-05-10 18:35:51,732 : INFO : 3 batches submitted to accumulate stats from 192 documents (198734 virtual)
# 2023-05-10 18:35:51,752 : INFO : 4 batches submitted to accumulate stats from 256 documents (253148 virtual)
# 2023-05-10 18:35:51,771 : INFO : 5 batches submitted to accumulate stats from 320 documents (309937 virtual)
# 2023-05-10 18:35:51,783 : INFO : 6 batches submitted to accumulate stats from 384 documents (345118 virtual)
# 2023-05-10 18:35:53,136 : INFO : 7 batches submitted to accumulate stats from 448 documents (387551 virtual)
# ...

# %%
def latex_print_topic(topic):
    for word in topic[0]:
        print(f"\\textit{{{word[1]}}} ({f'{round(word[0], 3):.3f}'}) \\newline")

# %%
for no, topic in enumerate(top_topics):
    for word in topic[0]:
        if word[1] == "ZKB":
            print(no)
            latex_print_topic(topic)
# Out:
# 41
# \textit{ZKB} (0.033) \newline
# \textit{Bank} (0.021) \newline
# \textit{Geschäftsbericht} (0.012) \newline
# \textit{Kantonalbank} (0.011) \newline
# \textit{Zürcher_Kantonalbank} (0.008) \newline
# \textit{Bankrat} (0.007) \newline
# \textit{Milliarden} (0.007) \newline
# \textit{Staatsgarantie} (0.007) \newline
# \textit{Banken} (0.005) \newline
# \textit{Milliarden_Franken} (0.005) \newline
# 96
# \textit{ZKB} (0.022) \newline
# \textit{WAK} (0.012) \newline
# \textit{Bank} (0.012) \newline
# \textit{Ueli} (0.011) \newline
# \textit{Bamert} (0.011) \newline
# \textit{Nachhaltigkeit} (0.009) \newline
# \textit{Ueli_Bamert} (0.009) \newline
# \textit{nachhaltige} (0.008) \newline
# \textit{finanziellen_Auswirkungen} (0.008) \newline
# \textit{Klimaschutz} (0.007) \newline

# %%
from pprint import pprint
#for idx, top_topic in enumerate(top_topics):
#    print(f"{idx}: {top_topic}")
pprint(top_topics[110])
latex_print_topic(top_topics[110])
# Out:
# ([(0.4686118, '23.'),
#   (0.112803265, '10.'),
#   (0.097437344, 'Änderung_vorgenommen'),
#   (0.09673746, '4._März'),
#   (0.06821662, 'Ustermer'),
#   (0.044491842, 'Zufahrt'),
#   (0.04201284, 'Allfällige'),
#   (0.03211829, 'unveränderte'),
#   (0.017280197, 'KEVU'),
#   (0.009940376, 'Redaktionslesung_Titel')],
#  0.3278578288597438)
# \textit{ausserhalb} (0.020) \newline
# \textit{Verdichtung} (0.019) \newline
# \textit{Raumplanung} (0.019) \newline
# \textit{Stiftungen} (0.015) \newline
# \textit{Siedlungsentwicklung} (0.013) \newline
# \textit{Bauzone} (0.012) \newline
# \textit{Wachstum} (0.012) \newline
# \textit{Aufsicht} (0.011) \newline
# \textit{Bauten} (0.009) \newline
# \textit{Stiftungsaufsicht} (0.008) \newline

# %%
model[corpus][0]
# Out:
# [(3, 0.01180542),
#  (8, 0.01541822),
#  (27, 0.010847042),
#  (49, 0.011104084),
#  (58, 0.0151013965),
#  (67, 0.015614999),
#  (78, 0.014055405),
#  (80, 0.06611639),
#  (83, 0.017718973),
#  (96, 0.018443458),
#  (99, 0.010055505),
#  (107, 0.012353314),
#  (110, 0.1289764),
#  (113, 0.017227734),
#  (116, 0.010764658),
#  (118, 0.0129896235),
#  (129, 0.011994795),
#  (137, 0.0135971075),
#  (143, 0.10278975),
#  (146, 0.010349942),
#  (147, 0.011421525)]

# %%
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()

lda_display = pyLDAvis.gensim_models.prepare(model, corpus, dictionary, R=10)
pyLDAvis.display(lda_display)
# Out:
# /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/pyLDAvis/_prepare.py:244: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el368601398187758497606380026331" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
# %pip install pyLDAvis
# Out:
# /bin/bash: /anaconda/envs/jupyter_env/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
len(corpus)
# Out:
# 2538

# %%
len(lemma_grouped)
# Out:
# 2538

# %%
lemma_grouped
# Out:
# iob_ident
# 396_1. Mitteilungen                                                                                                                                                                                   [Antworten, Anfragen, Regierungsrat, Antworten...
# 396_1a. Eintritt eines neuen Mitglieds des Kantonsrates                                                                                                                                               [Kantonsrat, zurückgetretenen, Andreas, Hauri,...
# 396_2. Wahl der Geschäftsleitung des Kantonsrates für das Amtsjahr 2018/2019                                                                                                                          [Präsidium, Vizepräsidien, Mitglieder, Sekreta...
# ...

# %%
lemma_grouped.head()
# Out:
# iob_ident
# 396_1. Mitteilungen                                                             [Antworten, Anfragen, Regierungsrat, Antworten...
# 396_1a. Eintritt eines neuen Mitglieds des Kantonsrates                         [Kantonsrat, zurückgetretenen, Andreas, Hauri,...
# 396_2. Wahl der Geschäftsleitung des Kantonsrates für das Amtsjahr 2018/2019    [Präsidium, Vizepräsidien, Mitglieder, Sekreta...
# 396_3. Änderung der Kantonsverfassung (Steuerfuss)                              [Max, Homberger, Grüne, Wetzikon, Beat, Monhar...
# 396_Verschiedenes                                                               [Gratulation, Regierungspräsidenten, Bevor, Wa...
# Name: lemma, dtype: object

# %%
df = pd.DataFrame(lemma_grouped)

# %%
len(df)
# Out:
# 2538

# %%
df
# Out:
#                                                                                                 lemma
# iob_ident
# 396_1. Mitteilungen                                 [Antworten, Anfragen, Regierungsrat, Antworten...
# 396_1a. Eintritt eines neuen Mitglieds des Kant...  [Kantonsrat, zurückgetretenen, Andreas, Hauri,...
# 396_2. Wahl der Geschäftsleitung des Kantonsrat...  [Präsidium, Vizepräsidien, Mitglieder, Sekreta...
# 396_3. Änderung der Kantonsverfassung (Steuerfuss)  [Max, Homberger, Grüne, Wetzikon, Beat, Monhar...
# 396_Verschiedenes                                   [Gratulation, Regierungspräsidenten, Bevor, Wa...
# ...                                                                                               ...
# 776_5. Versorgungsgrundlagen erhalten – Schutz ...  [Konrad, Langhart, Mitte, Stammheim, Hans, Egl...
# 776_6. Telemedizin ermöglichen                      [Claudia, Hollenstein, GLP, Stäfa, Andreas, Da...
# ...

# %%
list(lemma_grouped.index)
# Out:
# ['396_1. Mitteilungen',
#  '396_1a. Eintritt eines neuen Mitglieds des Kantonsrates',
#  '396_2. Wahl der Geschäftsleitung des Kantonsrates für das Amtsjahr 2018/2019',
#  '396_3. Änderung der Kantonsverfassung (Steuerfuss)',
#  '396_Verschiedenes',
#  '403_1. Mitteilungen',
#  '403_2. Wahl eines Mitglieds der Aufsichtskommission für Bildung und Gesundheit',
#  '403_3. Veröffentlichung der Petition bezüglich der jüdischen Schule an der Schöntalstrasse',
#  '403_4. Fristerstreckung für die Berichterstattung und Antragstellung zur Motion KR-Nr. 138/2015 betreffend Detaillierte Abstimmungsergebnisse gehören auf die Homepage des Kantonsrates',
#  '403_5. Beteiligung der Gemeinden an den Kosten der Ombudsperson',
#  '403_6. Revision des Finanzkontrollgesetzes (FKG)',
#  '403_7. Bewilligung eines Rahmenkredits für den Betrieb der Genossenschaft Theater für den Kanton Zürich (Spielzeiten 2018/19– 2023/24)',
# ...

# %%
df = pd.DataFrame({'iob': lemma_grouped.index, 'lemma': lemma_grouped.values})

# %%
df
# Out:
#                                                     iob  \
# 0                                   396_1. Mitteilungen
# 1     396_1a. Eintritt eines neuen Mitglieds des Kan...
# 2     396_2. Wahl der Geschäftsleitung des Kantonsra...
# 3     396_3. Änderung der Kantonsverfassung (Steuerf...
# 4                                     396_Verschiedenes
# ...                                                 ...
# 2533  776_5. Versorgungsgrundlagen erhalten – Schutz...
# 2534                     776_6. Telemedizin ermöglichen
# 2535  776_7. Standesinitiative zur sofortigen Wieder...
# 2536  776_8. Schaffung einer neuen Zone ausserhalb S...
# 2537  776_9. Standesinitiative zum sofortigen Stopp ...
#
#                                                   lemma
# 0     [Antworten, Anfragen, Regierungsrat, Antworten...
# 1     [Kantonsrat, zurückgetretenen, Andreas, Hauri,...
# 2     [Präsidium, Vizepräsidien, Mitglieder, Sekreta...
# 3     [Max, Homberger, Grüne, Wetzikon, Beat, Monhar...
# ...

# %%
df['topics'] = model[corpus]

# %%
def show_topics_for_idx(idx):
    df['topics'].iloc[idx]

df
# Out:
#                                                     iob  \
# 0                                   396_1. Mitteilungen
# 1     396_1a. Eintritt eines neuen Mitglieds des Kan...
# 2     396_2. Wahl der Geschäftsleitung des Kantonsra...
# 3     396_3. Änderung der Kantonsverfassung (Steuerf...
# 4                                     396_Verschiedenes
# ...                                                 ...
# 2533  776_5. Versorgungsgrundlagen erhalten – Schutz...
# 2534                     776_6. Telemedizin ermöglichen
# 2535  776_7. Standesinitiative zur sofortigen Wieder...
# 2536  776_8. Schaffung einer neuen Zone ausserhalb S...
# 2537  776_9. Standesinitiative zum sofortigen Stopp ...
#
#                                                   lemma  \
# 0     [Antworten, Anfragen, Regierungsrat, Antworten...
# 1     [Kantonsrat, zurückgetretenen, Andreas, Hauri,...
# 2     [Präsidium, Vizepräsidien, Mitglieder, Sekreta...
# 3     [Max, Homberger, Grüne, Wetzikon, Beat, Monhar...
# ...

# %%
df[df['iob'] == '754_3. Klimaschutz: Desinvestition der ZKB aus fossilen Investitionen']
# Out:
#                                                     iob  \
# 2478  754_3. Klimaschutz: Desinvestition der ZKB aus...
#
#                                                   lemma  \
# 2478  [Antrag, Kommission, Wirtschaft, Abgaben, 1., ...
#
#                                                  topics
# 2478  [(52, 0.022112882), (131, 0.093928434), (135, ...

# %%
df['topics'].iloc[5]
# Out:
# [(1, 0.01613469),
#  (4, 0.015312923),
#  (46, 0.01719407),
#  (57, 0.010043272),
#  (68, 0.015308125),
#  (80, 0.06201967),
#  (96, 0.011065546),
#  (99, 0.016073732),
#  (110, 0.0898888),
#  (120, 0.010208564),
#  (128, 0.01065263),
#  (136, 0.015992932),
#  (143, 0.05506673),
#  (145, 0.011911754)]

# %%
sorted(df['topics'].iloc[5], key=lambda t: t[1], reverse=True)
# Out:
# [(110, 0.0898888),
#  (80, 0.06201967),
#  (143, 0.05506673),
#  (46, 0.01719407),
#  (1, 0.01613469),
#  (99, 0.016073732),
#  (136, 0.015992932),
#  (4, 0.015312923),
#  (68, 0.015308125),
#  (145, 0.011911754),
#  (96, 0.011065546),
#  (128, 0.01065263),
#  (120, 0.010208564),
#  (57, 0.010043272)]

# %%
for topic_id, prob in sorted(df['topics'].iloc[2478], key=lambda t: t[1], reverse=True):
    print(f"{topic_id}, {prob}:")
    print(model.show_topic(topic_id))
# Out:
# 135, 0.7410227060317993:
# [('ZKB', 0.044131644), ('Bank', 0.026940433), ('Kantonalbank', 0.014257391), ('Bankrat', 0.011063438), ('Zürcher_Kantonalbank', 0.010237106), ('Staatsgarantie', 0.007513694), ('Milliarden', 0.0065790103), ('EU', 0.0064350097), ('AWU', 0.0063989344), ('Banken', 0.005888276)]
# 131, 0.09392843395471573:
# [('CO', 0.058273632), ('Klimaschutz', 0.023133362), ('Klimawandel', 0.014954473), ('Postulate', 0.0127456365), ('Klima', 0.012370889), ('null', 0.0092002), ('Klimapolitik', 0.007845167), ('Emissionen', 0.007445209), ('CO_-Gesetz', 0.007025504), ('-Gesetz', 0.007020704)]
# 52, 0.022112881764769554:
# [('Fahrzeuge', 0.056114566), ('Strassenfonds', 0.033651832), ('Verkehrsabgaben', 0.022963958), ('Autos', 0.020730002), ('Strassen', 0.016145669), ('WAK', 0.015800577), ('Abgaben', 0.013776254), ('Fahrzeugen', 0.012914342), ('Fahrzeug', 0.011009535), ('Lieferwagen', 0.010791501)]
# 148, 0.020800678059458733:
# ...
